# %% [markdown]
# ### Линейная алгебра
# ##### Домашнее задание №1

# %% [markdown]
# __1.__ Исследуйте на линейную зависимость:
#
# $$f_{1}(x)=e^{x}, f_{2}(x)=1, f_{3}(x)=x+1, f_{4}(x)=x-e^{x}.$$

# %% [markdown]
# __Решение__<br>
# Если присмотреться повнимательнее, то можно вектор $f_1(x)$ выразить через остальные три вектора:
# $$e^x=-(x-e^x)+(x+1)-1$$
# или
# $$f_1(x)=-f_4(x)+f_3(x)-f_2(x)$$
# Таким образом, первый вектор является комбинацией трех остальных, а значит они линейно зависимы между собой.

# %% [markdown]
# __2.__ Исследуйте на линейную зависимость:
# $$f_{1}(x)=2, f_{2}(x)=x, f_{3}(x)=x^{2}, f_{4}(x)=(x+1)^{2}$$

# %% [markdown]
# __Решение__<br>
# Еще раз смотрим внимательно на данные: $f_4(x)$ можно разложить по формуле квадрата суммы и получится:
# $$f_{4}(x)=(x+1)^{2}=x^2+2x+2$$
# В таком уже виде вектор $f_4(x)$ можно выразить через три остальных вектора:
# $$f_{4}(x)=x^2+2x+2=f_3(x)+2f_2(x)+f_1(x)$$
# Как и в первом задании один вектор можно выразить через три остальных, а значит они линейно зависимы.<br>
# __Примечание.__ Выше $2x$ выразил как $2f_2(x)$, а не $f_1(x)\times f_2(x)$, потому что в линейном пространстве можно умнжать на константу, а перемножать вектора нельзя.

# %% [markdown]
# __3.__ Найдите координаты вектора $x = (2, 3, 5)\in \mathbb{R}^{3}$ в базисе $b_{1}=(0, 0, 10)$, $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$.

# %% [markdown]
# __Решение__<br>
# $$x=b_2+3b_3+\frac{b_1}{2}$$
# то есть координаты вектора $x$ в заданном базисе будут (1/2; 1; 3)

# %% [markdown]
# __4.__ Найдите координаты вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$:
#
# а) в базисе $1$, $x$, $x^{2}$;
#
# б) в базисе $x^{2}$, $x-1$, $1$.

# %% [markdown]
# __Решение__<br>
# а) Запишем коэффициенты соответствующие порядку в базисе: 2, -2, 3. Таким образом координаты вектора в заданном базисе будут (2; -2; 3).
# <br>
# б) Проведем небольшое преобразование исходного вектора:
# $$3x^2-2x+2=3x^2-2(x-1)+0$$
# Далее по той же схеме: (3, -2, 0).

# %% [markdown]
# __5.__ Установите, считается ли линейным подпространством:
#
# а) совокупность всех векторов трёхмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;
#
# б) все векторы, считающиеся линейными комбинациями данных векторов  {𝑢1,𝑢2…,𝑢𝑛} .

# %% [markdown]
# __Решение__<br>
# a) Чтобы проверить, является ли совокупность всех векторов трёхмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю линейным подпространством, проверим выполнение основных операций для линейного пространства, а именно сложение и умножение на константу.<br>
# Возьмем три вектора со следующими координатами:
# $$(0, a, b), (c, 0, d), (0, 0, f)$$
# Попробуем их сложить и посмотрим, что получится:
# $$(0, a, b)+(c, 0, d)+(0, 0, f)=(c, a, b+d+f)$$
# У нас получились координаты вектора, у которого ни одна из первых двух координат не равна нулю. А значит назвать данное подпространство линейным нельзя.<br>
# <br>
# б) Для проверки возьмем два вектора, являющиеся линейными комбинациями данных векторов  {𝑢1,𝑢2…,𝑢𝑛}, проверим сложение векторов и умножение на константу.
# $$a=\lambda_1\cdot u_1+\lambda_2\cdot u_2+...+\lambda_n\cdot u_n$$
# $$b=\mu_1\cdot u_1+\mu_2\cdot u_2+...+\mu_n\cdot u_n$$
# $$a+b=\lambda_1\cdot u_1+\mu_1\cdot u_1+\lambda_2\cdot u_2+\mu_2\cdot u_2+...+\lambda_n\cdot u_n+\mu_n\cdot u_n=(\lambda_1+\mu_1)\cdot u_1+(\lambda_2+\mu_2)\cdot u_2+...+(\lambda_n+\mu_n)\cdot u_n$$
# Согласно правилу дистрибутивности относительно сложения скаляров. Таким образом, сложение векторов удовлетворяет условию линейного пространства.<br>
# Теперь проверим умножение на константу:
# $$\alpha \cdot a=\alpha \cdot \lambda_1\cdot u_1+\alpha \cdot \lambda_2\cdot u_2+...+\alpha \cdot \lambda_n\cdot u_n=(\alpha \cdot \lambda_1)u_1+(\alpha \cdot \lambda_2)u_2+...+(\alpha \cdot \lambda_n)u_n$$
# Согласно правилу ассоциативности операции умножения на скаляр. Умножение на константу также удовлетворяет условию линейного пространства.<br>
# Таким образом данный вариант считается линейным подпространством.

# %% [markdown]
# ##### Домашнее задание №2

# %% [markdown]
# __1.__ Найдите скалярное произведение векторов $x, y \in \mathbb{R}$:<br>
# а) $x=(0,-3, 6),~y=(-4, 7, 9);$<br>
# б) $x=(7, -4, 0, 1),~y=(-3, 1, 11, 2).$

# %% [markdown]
# __Решение__<br>
# a) <i>Вручную</i><br>
# $(x,y)=0\times (-4)+(-3)\times 7 + 6\times9=-21+54=33$

# %%
# решение в коде
import numpy as np

x_a = np.array([0, -3, 6])
y_a = np.array([-4, 7, 9])

print(f'Скалярное произведение векторов x и y: {x_a.dot(y_a)}')
# Out:
# Скалярное произведение векторов x и y: 33

# %% [markdown]
# б) <i>Вручную</i><br>
# $(x,y)=7\times (-3)+(-4)\times 1 + 0\times 11 + 1\times 2=-25+2=-23$

# %%
# решение в коде

x_b = np.array([7, -4, 0, 1])
y_b = np.array([-3, 1, 11, 2])

print(f'Скалярное произведение x и y: {x_b.dot(y_b)}')
# Out:
# Скалярное произведение x и y: -23

# %% [markdown]
# __2.__ Найдите нормы векторов $(4, 2, 4)$ и $(12, 3, 4)$ и угол между ними.

# %% [markdown]
# __Решение__<br>
# <i>Вручную</i><br>
# Для простоты обзовем вектора буквами:
#
# m = (4, 2, 4)
# n = (12, 3, 4)
#
# Определим манхэттенскую норму векторов:
#
# $$\left\|m\right\|_{1} = |4|+|2|+|4|=10$$
# $$\left\|n\right\|_{1} = |12|+|3|+|4|=19$$
#
# Определим эвклидову норму векторов:
#
# $$\left\|m\right\|_{2} = \sqrt{4^2+2^2+4^2}=\sqrt{36}=6$$
# $$\left\|n\right\|_{2} = \sqrt{12^2+3^2+4^2}=\sqrt{169}=13$$
#
# Определим угол между векторами:
#
# $$cos\alpha = \frac{4\cdot12+2\cdot3+4\cdot4}{6\cdot 13}=\frac{70}{78}\approx 0.897$$
# $$\alpha \approx 26,23^{\circ} или 0,46 радиан$$

# %%
# решение в коде
from numpy.linalg import norm
from math import *

m = np.array([4, 2, 4])
n = np.array([12, 3, 4])

print(f'l1 Манхэттенская норма вектора m: {norm(m, ord=1)}')
print(f'l1 Манхэттенская норма вектора n: {norm(n, ord=1)}')

print(f'l2 Эвклидова норма вектора m: {norm(m)}')
print(f'l2 Эвклидова норма вектора n: {norm(n)}')

cos_alpha = m.dot(n) / norm(m) / norm(n)
print(f'Косинус угла между векторами m и n: {cos_alpha:.3f}')
print(f'Угол между векторами m и n: {acos(cos_alpha):.2f} радиан')
# Out:
# l1 Манхэттенская норма вектора m: 10.0
# l1 Манхэттенская норма вектора n: 19.0
# l2 Эвклидова норма вектора m: 6.0
# l2 Эвклидова норма вектора n: 13.0
# Косинус угла между векторами m и n: 0.897
# Угол между векторами m и n: 0.46 радиан

# %% [markdown]
# __3.__ Определите, будет ли линейное пространство евклидовым, если за скалярное произведение принять:<br>
# а) произведение длин векторов;<br>
# б) утроенное обычное скалярное произведение векторов?<br>

# %% [markdown]
# а) Скалярное произведение двух векторов определяется как произведение длин этих векторов на косинус угла между ними:
#
# $$(x, y) = \left|x\right|\cdot\left|y\right|\cdot cos\alpha.$$
#
# Соответственно, если за скалярное произведение принять произведение длин векторов, то линейное пространство можно считать евклидовым только в единственном случае, когда $cos\alpha=0$, или угол между векторами x и y $\alpha=\pi n, n\in\mathbb{N}$.
# <br>В остальных случаях линейное пространство нельзя считать евклидовым.

# %% [markdown]
# б) Утроенное обычное скалярное произведение векторов x и y будет иметь вид: $$\lambda(x,y),$$
# где $\lambda=3.$
# Данное выражение не противоречит второй аксиоме:
# $(\lambda x, y)=\lambda(x, y).$<br>
# Таким образом, в данном случае линейное пространство можно считать евклидовым.

# %% [markdown]
# __4.__ Выясните, какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве $\mathbb{R}^{3}$:<br>
# а) $(1,0,0),(0,0,1);$ <br>
# б) $(1/\sqrt{2},-1/\sqrt{2},0),(1/\sqrt{2},1/\sqrt{2},0), (0,0,1);$<br>
# в) $(1/2, -1/2, 0), (0, 1/2, 1/2), (0,0,1);$<br>
# г) $(1,0,0),(0,1,0),(0,0,1)?$

# %% [markdown]
# __Определение.__ В конечномерном евклидовом пространстве базис $\{e_{1},e_{2}...,e_{n}\}$ называется ортонормированным, если:
#
# $(e_{i}, e_{j})=0$ $\forall$ $i\neq j$ и $(e_{i},e_{i})=1$ $\forall$ $i\in[1, n].$

# %% [markdown]
# а)  (1,0,0),(0,0,1);
#
# Скалярное произведение данных векторов равно:
# $$1\cdot 0 + 0\cdot0 + 0\cdot 1 = 0$$
# А скалярное произведение первого вектора самого на себя равно:
# $$1\cdot 1 + 0\cdot0 + 0\cdot 0 = 1$$
# Условие из определения выполняется, соответственно данные вектора образуют ортонормированный базис.

# %% [markdown]
# б) $(1/\sqrt{2},-1/\sqrt{2},0),(1/\sqrt{2},1/\sqrt{2},0), (0,0,1);$<br>
# В данном случае посчитаем скалярные произведения для трех комбинаций пар:
# $$1. \quad \frac{1}{\sqrt 2}\cdot \frac{1}{\sqrt 2} + \frac{-1}{\sqrt 2}\cdot \frac{1}{\sqrt 2} + 0\cdot 1 =\frac{1}{2} - \frac{1}{2} + 0 = 0$$
# $$2. \quad \frac{1}{\sqrt 2}\cdot 0 + \frac{-1}{\sqrt 2}\cdot 0 + 0\cdot 1 =0 + 0 + 0 = 0$$
# $$3. \quad \frac{1}{\sqrt 2}\cdot 0 + \frac{1}{\sqrt 2}\cdot 0 + 0\cdot 1 =0 + 0 + 0 = 0$$
# Скалярное произведение первого вектора на самого себя равно:
# $$\frac{1}{\sqrt 2}\cdot \frac{1}{\sqrt 2} + \frac{-1}{\sqrt 2}\cdot \frac{-1}{\sqrt 2} + 0\cdot 0 =\frac{1}{2} + \frac{1}{2} + 0 = 1$$
# Условие из определения выполняется, соответственно данные вектора образуют ортонормированный базис.

# %% [markdown]
# в) $(1/2, -1/2, 0), (0, 1/2, 1/2), (0,0,1);$<br>
#
# Посчитаем скалярные произведения трех пар:
# $$1. \quad \frac{1}{2}\cdot 0 + \frac{-1}{2}\cdot \frac{1}{2} + 0\cdot\frac{1}{2} = \frac{-1}{4}$$
# $$2. \quad \frac{1}{2}\cdot 0 + \frac{-1}{2}\cdot 0 + 0\cdot 1 = 0$$
# $$3. \quad 0\cdot 0 + \frac{1}{2}\cdot 0 + \frac{1}{2}\cdot 1 = \frac{1}{2}$$
#
# Скалярные произведения 1 и 2, а также 2 и 3 векторов не равны 0, значит угол между ними не равен $90^{\circ}.$
# Условие из определения не выполнено, значит данные вектора не образуют ортонормированный базис.

# %% [markdown]
# г) $(1,0,0),(0,1,0),(0,0,1)$<br>
# В данном примере очевидно, что вектора образуют стандартный ортонормированный базис. Однако, для тренировки, можно снова посчитать три пары скалярных произведений.
# $$1. \quad 1\cdot0+0\cdot1+0\cdot0=0$$
# $$2. \quad 1\cdot0+0\cdot0+0\cdot1=0$$
# $$3. \quad 0\cdot0+1\cdot0+0\cdot1=0$$
# Скалярное произведение любого из данных трех векторов самого на себя равно единице. Данные вектора образуют ортонормированный базис.
