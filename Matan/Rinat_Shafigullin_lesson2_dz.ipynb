# %% [markdown]
# ### Домашнее задание к уроку 2
# ##### 1. Прочитать высказывания математической логики, построить их отрицания и установить истинность

# %% [markdown]
# 1) $$\forall y \in [0; 1]: sgn(y) = 1$$
#
# Данное высказывание читается как "Для любого y принадлежащего отрезку от 0 включительно до 1 включительно верно
# утверждение, что значение функции сигнум от у равно 1"
#
# <b>Решение:</b>
# Функция sgn(y) определяется следующим образом:
#
# $$sgn(y) = \begin{cases}
#                 1, & \quad \text{при } y\text{>0,} \\
#                 0, & \quad \text{при } y\text{=0,} \\
#                 -1, & \quad \text{при } y\text{<0}
#             \end{cases}$$
#
# Исходя из определения функции сигнум, y не может быть равен 1 в точке 0. Значит, данное высказывание ложно.
#
# Построим отрицание высказывания
# $$\exists y \in [0; 1]: sgn(y) \neq 1$$
#
# Данное высказывание читается как "Существует хотя бы один y принадлежащего отрезку от 0 включительно до 1 включительно такой, что значение функции сигнум от у не равно 1".
# Исходя из определения функции сигнум, в точке 0 значение функции равно 0, т.е. не равно 1. Значит отрицание первоначального высказывания является истиной, что подтверждает ложность первоначального высказывания.

# %% [markdown]
# 2) $$\forall n \in {N}>2: \exists x, y, z \in {N}: x^n=y^n+z^n$$
#
# Данное высказывание читается следующим образом: "Для любого n, принадлежащего множеству натуральных чисел и больше 2 верно утверждение, что существует хотя бы одно значение x, y, z принадлежащих множеству натуральных чисел, такие что x в степени n равняется сумме y в степени n и z в степени n"
#
# <b>Решение:</b> Теорема Ферма утверждает, что для любого натурального числа n>2 уравнение $$x^n=y^n+z^n$$ <b><u>не имеет</u></b> решений в целых ненулевых числах x, y, z. Значит, данное высказывание ложно.
#
# Построим отрицание высказывания:
# $$\exists n \in {N}>2: \forall x, y, z \in {N}: x^n \neq y^n+z^n$$
# Данное высказывание читается следующим образом: "Существует хотя бы одно значение n, принадлежащее множеству натуральных чисел и больше 2 такое, что для любых значений x, y, z принадлежащих множеству натуральных чисел, верно утверждение, что x в степени n не равняется сумме y в степени n и z в степени n"
#
# Выберем для x значение равное 1, а y и z не равные 1 получим, что 1 в степени n не равно сумме любых других натуральных чисел в степени n, что является истиной, и подтверждает ложность первоначального высказывания.

# %% [markdown]
# 3) $$\forall x \in {R} \exists X \in {R}: X>x$$
#
# Данное высказывание читается следующим образом: "Для любого <i>x</i>, принадлежащего множеству вещественных чисел существует хотя бы одно значение <i>X</i>, принадлежащий множеству вещественных чисел, такое, что <i>X</i> больше <i>x</i>".
#
# <b>Решение:</b> Одним из свойств множества вещественных чисел является его бесконечность. Это значит, что к любому элементу множества всегда можно прибавить некоторое значение и получить новый элемент множества, который будет больше первоначального. Отсюда следует, что первоначальное высказывание истинно.
#
# Построим отрицание высказывания:
# $$\exists x \in {R} \forall X \in {R}: X\leq x$$
#
# Данное высказывание читается следующим образом: "Существует хотя бы одно значение <i>x</i>, принадлежащее множеству вещественных чисел, при этом для любых значений <i>X</i>, принадлежащего множеству вещественных чисел, будет справедливо, что <i>X</i> меньше или равно <i>x</i>".
# Иными словами, какое бы значение <i>X</i> из множества вещественных чисел мы ни взяли, оно всегда будет меньше или равно значения <i>x</i> из множества вещественных чисел. Проще говоря, у множества вещественных чисел есть конечное значение и оно равно <i>x</i>, но это противоречит свойству бесконечности множества вещественных чисел. Таким образом, отрицание первоначального высказывания ложно, а это доказывает истинность первоначального высказывания.

# %% [markdown]
# 4) $$\forall x \in {C} \nexists y \in {C}: x>y\|x<y$$
#
# Данное высказывание читается следующим образом: "Для любого x, принадлежащего множеству комплексных чисел не существует y, принадлежащего множеству комплексных чисел, такое что x больше y или x меньше y". Иными словами, данное высказывание утверждает, что во множестве комплексных чисел любое число x равно любому числу y.
#
# <b>Решение:</b> Множество комплексных чисел включает в себя также другие множества, в том числе и множество натуральных чисел N, элементы которого отличаются друг от друга и применяются для счета предметов:
# $${N} = \{1, 2, 3, 4, ... n, n+1 \}$$
# Таким образом, первоначальное высказывание ложно.
#
# Построим отрицание высказывания:
# $$ \exists x \in {C} \exists y \in {C}: x\leq y\&x\geq y$$
#
# Данное высказывание читается следующим образом: "Существует хотя бы одно значение х, принадлежащее множеству комплексных чисел и существует хотя бы одно значение у, принадлежащее множеству комплексных чисел, такие что х меньше или равно у и х больше или равно у". Условие 𝑥≤𝑦&𝑥≥𝑦 выполняется в одном случае, когда 𝑥=𝑦.Таким образом, отрицание первоначального высказывания истинно, что доказывает ложность первоначального высказывания.

# %% [markdown]
# 5) $$\forall y \in [0; \frac{\pi}{2}] \exists \epsilon >0: \sin y < \sin(y+\epsilon)$$
#
# Данное высказывание читается следующим образом: "Для любого у принадлежащем отрезку от 0 включительно до пи-пополам включительно существует хотя бы одно значение эпсилон больше 0, такое что значение синус у меньше значения синуса у+эпсилон".
#
# <b>Решение:</b> Функция sin(y) является периодической, с максимумом в точках 𝜋/2+2𝜋n. Отсюда следует, что значение sin(𝑦+𝜖) в точке 𝜋/2, при 𝜖>0 будет меньше значения sin(𝑦). Таким образом, высказывание является ложным.
#
# Построим отрицание высказывания:
# $$\exists y \in [0; \frac{\pi}{2}] \forall \epsilon >0: \sin y \geq \sin(y+\epsilon)$$
#
# Данное высказывание читается следующим образом: "Существует хотя бы одно значение y принадлежащее отрезку от 0 включительно до пи-пополам включительно и для любого эпсилон больше 0 справедливо утверждение, что синус у больше или равен синуса у плюс эпсилон".
#
# Функция sin(y) является периодической, с максимумом в точках 𝜋/2+2𝜋n. При любом 0<𝜖<2𝜋 значение sin(𝑦+𝜖) будет меньше значения sin(𝑦), при 𝜖=2𝜋, sin(𝑦)=sin(𝑦+𝜖). Таким образом, отрицание первоначального высказывания является истинным, что подтверждает ложность первоначального высказывания.

# %% [markdown]
# 6) $$\forall y \in [0; \pi) \exists \epsilon >0: \cos y > \cos(y+\epsilon)$$
#
# Данное высказывание читается следующим образом: "Для любого значения у принадлежащего полуинтервалу от 0 включительно до пи НЕвключительно существует хотя бы одно значение эпсилон больше 0, такое что значение косинус у больше значения косинуса у+эпсилон".
#
# <b>Решение</b>: Функция cos(y) является периодической, с максимумом в точках 2𝜋n и минимумах в точках 𝜋+2𝜋n. Отсюда следует, что на полуинтервале \[0;𝜋) при приближении к точке 𝑦=𝜋 всегда найдется хотя бы одно значение 𝜖>0, такое, что cos(𝑦+𝜖) будет меньше значения cos(𝑦). Таким образом, высказывание является истинным.
#
# Построим отрицание высказывания:
#
# $$\exists y \in [0; \pi) \forall \epsilon >0: \cos y \leq \cos(y+\epsilon)$$
#
# Данное высказывание читается следующим образом: "Существует хотя бы одно значение y принадлежащее полуинтервалу от 0 включительно до пи невключительно и для любого эпсилон больше 0 справедливо утверждение, что значение косинус у меньше или равно значения косинуса у+эпсилон". Данное высказывание является ложью, так как если значение (𝑦+𝜖) лежит в полуинтервале [0;𝜋), то cos(𝑦) будет больше cos(𝑦+𝜖). Это доказывает истинность первоначального высказывания.

# %% [markdown]
# 7) $$\exists x: x\notin \left\{{N},{Z},{Q},{R},{C}\right\}$$
# Данное высказывание читается следующим образом: "Существует хотя бы одно значение х, такое что х не принадлежит множеству множеств натуральных, целых, рациональных, вещественных и комплексных чисел".
#
# <b>Решение</b>: В задании не определено, чем является элемент х. По определению - элемент х принадлежит множеству А, если в множестве А содержится элемент х. В нашем задании большое множество содержит только элементы N, Z, Q, R и C, являющиеся множествами. Если х определить как любое число (букву, слово, предмет), то данное высказывание является истинным.
#
# Построим отрицание высказывания:
# $$\forall x: x\in \left\{{N},{Z},{Q},{R},{C}\right\}$$
# Данное высказывание читается следующим образом: "Для любого х справедливо утверждение, что х принадлежит множеству из множеств натуральных, целых, рациональных, вещественных и комплексных чисел". В нашем большом множестве всего 5 элементов, а по условию х может принимать любые значения. Так как любых значений бесконечное множество, а элементов большого множества всего 5, то отрицание исходного высказывания является ложным.

# %% [markdown]
# ##### 2) Даны три множества a, b и c. Необходимо выполнить все изученные виды бинарных операций над всеми комбинациями множеств.

# %% [markdown]
# A = {0, 1, 2, 3, 4}<br>
# B = {2, 3, 4, 5, 'шесть', 'семь'}<br>
# C = {3, 4, 5, 9, 'семь', 'десять'}<br>
#
# <b>Объединение (дизъюнкция)</b>
# $$A \vee B = \{0, 1, 2, 3, 4, 5, 'шесть', 'семь'\} $$
# $$A \vee C = \{0, 1, 2, 3, 4, 5, 9, 'семь', 'десять'\} $$
# $$B \vee C = \{2, 3, 4, 5, 9, 'шесть', 'семь', 'десять'\} $$
# $$A \vee B \vee С = \{0, 1, 2, 3, 4, 5, 9, 'шесть', 'семь', 'десять'\} $$
#
# <b>Пересечение (конъюнкция)</b>
# $$A \wedge B = \{2, 3, 4\}$$
# $$A \wedge С = \{3, 4\}$$
# $$B \wedge C = \{3, 4, 5, 'семь'\}$$
# $$A \wedge B \wedge С = \{3, 4\}$$
#
# <b>Разность</b>
# $$A \backslash B = \{0, 1\}$$
# $$B \backslash A = \{5, 'шесть', 'семь'\}$$
# $$B \backslash C = \{2, 'шесть'\}$$
# $$C \backslash B = \{9, 'десять'\}$$
# $$A \backslash C = \{0, 1, 2\}$$
# $$C \backslash A = \{5, 9, 'семь', 'десять'\}$$
#
# <b>Симметрическая разность</b>
# $$A \Delta B = \{0, 1, 5, 'шесть', 'семь'\}$$
# $$A \Delta C = \{0, 1, 2, 5, 9, 'семь', 'десять'\}$$
# $$B \Delta C = \{2, 9, 'шесть', 'десять'\}$$

# %%
# It is Python time, let the coding begin

# Задаем множества А, В, С
A = {0, 1, 2, 3, 4}
B = {2, 3, 4, 5, 'шесть', 'семь'}
C = {3, 4, 5, 9, 'семь', 'десять'}

#Объединение (дизъюнкция)
print(f'Объединение (дизъюнкция) множеств А и В = {B.union(A)}')
print(f'Объединение (дизъюнкция) множеств А и C = {C.union(A)}')
print(f'Объединение (дизъюнкция) множеств B и C = {C.union(B)}')
print('') #Пустая строка
#Пересечение (конъюнкция)
print(f'Пересечение (конъюнкция) множеств А и В = {B.intersection(A)}')
print(f'Пересечение (конъюнкция) множеств А и C = {C.intersection(A)}')
print(f'Пересечение (конъюнкция) множеств B и C = {C.intersection(B)}')
print(f'Пересечение (конъюнкция) множеств А, B и C = {C.intersection(B.intersection(A))}')
print('') #Пустая строка
#Разность
print(f'Разность множеств А и В = {A.difference(B)}')
print(f'Разность множеств B и A = {B.difference(A)}')
print(f'Разность множеств B и C = {B.difference(C)}')
print(f'Разность множеств C и B = {C.difference(B)}')
print(f'Разность множеств А и C = {A.difference(C)}')
print(f'Разность множеств C и A = {C.difference(A)}')
print('') #Пустая строка
#Симметрическая разность
print(f'Симметрическая разность множеств А и В = {B.symmetric_difference(A)}')
print(f'Симметрическая разность множеств А и C = {C.symmetric_difference(A)}')
print(f'Симметрическая разность множеств B и C = {C.symmetric_difference(B)}')
# Out:
# Объединение (дизъюнкция) множеств А и В = {0, 1, 2, 3, 4, 5, 'шесть', 'семь'}
# Объединение (дизъюнкция) множеств А и C = {0, 1, 2, 3, 4, 5, 9, 'семь', 'десять'}
# Объединение (дизъюнкция) множеств B и C = {2, 3, 4, 5, 'шесть', 9, 'семь', 'десять'}
#
# Пересечение (конъюнкция) множеств А и В = {2, 3, 4}
# Пересечение (конъюнкция) множеств А и C = {3, 4}
# Пересечение (конъюнкция) множеств B и C = {3, 4, 5, 'семь'}
# Пересечение (конъюнкция) множеств А, B и C = {3, 4}
#
# Разность множеств А и В = {0, 1}
# Разность множеств B и A = {'шесть', 5, 'семь'}
# Разность множеств B и C = {'шесть', 2}
# Разность множеств C и B = {9, 'десять'}
# Разность множеств А и C = {0, 1, 2}
# Разность множеств C и A = {9, 5, 'семь', 'десять'}
#
# Симметрическая разность множеств А и В = {0, 1, 5, 'шесть', 'семь'}
# Симметрическая разность множеств А и C = {0, 1, 2, 5, 9, 'семь', 'десять'}
# Симметрическая разность множеств B и C = {2, 'шесть', 9, 'десять'}
