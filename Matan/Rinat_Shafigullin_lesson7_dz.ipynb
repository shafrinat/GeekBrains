# %% [markdown]
# ### Домашнее задание к уроку 7
# ### "Производная функции одной переменной. Часть 2"

# %% [markdown]
# ##### Задание №1
# Найти длину 𝑥 и ширину 𝑦 прямоугольника при заданном периметре 𝑃=144 cм, при которых данный прямоугольник имеет наибольшую площадь 𝑆.
# Чтобы найти наибольшую площадь при заданном периметре, составим функцию площади прямоугольника и найдем ее максимум.
# $$S=x\times y$$
# Чтобы избавиться от второй переменной, выразим y через x из формулы периметра:
# $$P=2x+2y=144см$$<br>
# $$y=\frac{144-2x}{2}$$
# Теперь подставим и раскроем скобки:
# $$S=\frac{x\cdot (144-2x)}{2}=\frac{144x-2x^2}{2}=72x-x^2$$
# Функция площади прямоугольника имеет квадратичный вид, график - парабола, направленная "рожками" вниз (коэффициент -1 при x^2).
# Также, вынеся х за скобку легко находятся корни х1=0, х2=72. Вопрос: для чего мне корни функции площади, если надо искать производную и находить ее "ноль"? Ответ: Зная, что парабола есть кривая с вертикальной осью симметрии, осмелюсь предположить, что максимум функции площади расположен в точке, равноудаленной от ее нулей, то есть х0=(0+72)/2=36. Проверим предположение, пойдя традиционным путем:
# $$S(x)=72x-x^2$$
# $$S'(x)=72-2x$$
# Необходимое условие экстремума: производная в этой точке равна 0 или не существует. Область определения S'(x) есть вся числовая прямая, никаких ограничений не накладывается. Поэтому поищем точку в которой производная равна 0.
# $$72-2x=0\\
# 2x=72\\
# x=36$$
# Достаточное условие экстремума: при переходе через точку "ноль" производная меняет знак.
# Для проверки возьмем точки x1=0 и x2=37. При x1=0 S'(x)=72, при x2=37 S'(x)=-2. Проходя через точку x=36 производная меняет знак, значит это точка экстремума. При этом, при x<36 производная положительна и функция площади возрастает, а при x>36 производная отрицательна и функция площади убывает. Отсюда следует - точка х=36 это точка максимума функции площади. Предположение было верным.
# Зная х, найдем у:
# $$y=\frac{144-2\times36}{2}=36см$$
# <b>Ответ:</b> Наибольшая площадь прямоугольника с периметром P=144см достигается при сторонах х=36см и у=36см, то есть это квадрат.

# %% [markdown]
# ##### №2. найти экстремумы функций (если они есть)
# 1) y = |2x|<br>
# 2) y=xˆ3<br>
# 3) y = eˆ(3x) (или то же самое, что еxp(3x))<br>
# 4) y=xˆ3-5x<br>
# Поехали:
# Для нахождения экстремума функции первым шагом найдем ее производную, затем найдем точку в которой производная равна 0 или не существует, и проверим, меняется ли знак производной при переходе через эту точку.
# 1. $$y=|2x|\\
# y'=\frac{2x}{|x|}$$
# Необходимое условие экстремума: в точке х=0 производная не существует, так как х стоит в знаменателе.<br>
# Достаточное условие экстремума: y'(-1)=-2; y'(1)=2. Производная меняет знак при переходе через точку х=0<br>
# Ответ: Экстремум функции y = |2x| находится в точке х=0.<br>
# <br>
# 2. $$y=x^3$$
# $$y'=3x^2$$
# Этот пример разбирался на 7 уроке, график не имеет экстремума, но имеет перегиб. Хоть и не интересно, но сейчас я это докажу.<br>
# Необходимое условие экстремума:<br>Производная существует на всей числовой оси.$$3x^2=0\\x=0$$
# Производная равна нулю в точке х=0.<br>
# Достаточное условие экстремума:<br>
# у(-1)=3, у(1)=3. При переходе через точку х=0 знак производной не поменялся, а значит х=0 не точка экстремума, а точка перегиба.<br>
# <br>
# 3. $$y=e^{3x}$$
# $$y'=(e^{3x})'=3e^{3x}$$
# Необходимое условие экстремума:<br>Производная существует на всей числовой оси.$$3e^{3x}=0$$
# У данного уравнения нет действительного корня, а значит нет точки, в которой y'(x)=0<br>
# Необходимое условие экстремума не соблюдается, а значит у функции y=xˆ3 нет точки экстремума.<br>
# <br>
# 4. $$y=x^3-5x\\
# y'=3x^2-5$$
# Необходимое условие экстремума:<br>
# Производная существует на всей числовой оси.$$3x^2-5=0\\
# x^2=\frac{5}{3}\\
# x_{1, 2}=\pm\sqrt{\frac{5}{3}}\approx\pm1.29$$
# Достаточное условие экстремума:<br>
# y'(-2)=7>0<br>
# y'(0)=-5<0<br>
# y'(2)=7>0<br>
# При переходе через точки х1 и х2 производная меняет свой знак, отсюда следует, что это есть точки экстремума. При этом х1=-1,29 - точка локального максимума, а х2=1,29 - точка локального минимума. Глобальные максимум и минимум найти невозможно, так как область допустимых значений функции лежит в бесконечностях.
